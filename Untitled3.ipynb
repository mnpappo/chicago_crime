# %%
from __future__ import print_function, division

import numpy as np
from keras.layers import Convolution1D, Dense, MaxPooling1D, Flatten
from keras.models import Sequential


def make_timeseries_regressor(window_size, filter_length, nb_input_series=1, nb_outputs=1, nb_filter=4):
    model = Sequential((
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu', input_shape=(window_size, nb_input_series)),
        MaxPooling1D(),     # Downsample the output of convolution by 2X.
        Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu'),
        MaxPooling1D(),
        Flatten(),
        Dense(nb_outputs, activation='linear'),     # For binary classification, change the activation to 'sigmoid'
    ))
    model.compile(loss='mse', optimizer='adam', metrics=['mae'])
    return model


def make_timeseries_instances(timeseries, window_size):
    timeseries = np.asarray(timeseries)
    assert 0 < window_size < timeseries.shape[0]
    X = np.atleast_3d(np.array([timeseries[start:start + window_size] for start in range(0, timeseries.shape[0] - window_size)]))
    y = timeseries[window_size:]
    q = np.atleast_3d([timeseries[-window_size:]])
    return X, y, q


def evaluate_timeseries(timeseries, window_size):
    filter_length = 5
    nb_filter = 4
    timeseries = np.atleast_2d(timeseries)
    if timeseries.shape[0] == 1:
        timeseries = timeseries.T 

    nb_samples, nb_series = timeseries.shape
    print('\n\nTimeseries ({} samples by {} series):\n'.format(nb_samples, nb_series), timeseries)
    model = make_timeseries_regressor(window_size=window_size, filter_length=filter_length, nb_input_series=nb_series, nb_outputs=nb_series, nb_filter=nb_filter)
    print('\n\nModel with input size {}, output size {}, {} conv filters of length {}'.format(model.input_shape, model.output_shape, nb_filter, filter_length))
    model.summary()

    X, y, q = make_timeseries_instances(timeseries, window_size)
    print('\n\nInput features:', X, '\n\nOutput labels:', y, '\n\nQuery vector:', q, sep='\n')
    test_size = int(0.01 * nb_samples)           # In real life you'd want to use 0.2 - 0.5
    X_train, X_test, y_train, y_test = X[:-test_size], X[-test_size:], y[:-test_size], y[-test_size:]
    model.fit(X_train, y_train, nb_epoch=25, batch_size=2, validation_data=(X_test, y_test))

    pred = model.predict(X_test)
    print('\n\nactual', 'predicted', sep='\t')
    for actual, predicted in zip(y_test, pred.squeeze()):
        print(actual.squeeze(), predicted, sep='\t')
    print('next', model.predict(q).squeeze(), sep='\t')


def main():
    """Prepare input data, build model, evaluate."""
    np.set_printoptions(threshold=25)
    ts_length = 1000
    window_size = 50

    print('\nSimple single timeseries vector prediction')
    timeseries = np.arange(ts_length)                 
    evaluate_timeseries(timeseries, window_size)

    print('\nMultiple-input, multiple-output prediction')
    timeseries = np.array([np.arange(ts_length), -np.arange(ts_length)]).T  
    evaluate_timeseries(timeseries, window_size)


if __name__ == '__main__':
    main()
# Out:
# Simple single timeseries vector prediction
#
#
# Timeseries (1000 samples by 1 series):
#  [[  0]
#  [  1]
#  [  2]
#  ...,
#  [997]
#  [998]
#  [999]]
#
#
# Model with input size (None, 50, 1), output size (None, 1), 4 conv filters of length 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 46, 4)             24
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 23, 4)             0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 19, 4)             84
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 9, 4)              0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 36)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 37
# =================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Input features:
# [[[  0]
#   [  1]
#   [  2]
#   ...,
#   [ 47]
#   [ 48]
#   [ 49]]
#
#  [[  1]
#   [  2]
#   [  3]
#   ...,
#   [ 48]
#   [ 49]
#   [ 50]]
#
#  [[  2]
#   [  3]
#   [  4]
#   ...,
#   [ 49]
#   [ 50]
#   [ 51]]
#
#  ...,
#  [[947]
#   [948]
#   [949]
#   ...,
#   [994]
#   [995]
#   [996]]
#
#  [[948]
#   [949]
#   [950]
#   ...,
#   [995]
#   [996]
#   [997]]
#
#  [[949]
#   [950]
#   [951]
#   ...,
#   [996]
#   [997]
#   [998]]]
#
#
# Output labels:
# [[ 50]
#  [ 51]
#  [ 52]
#  ...,
#  [997]
#  [998]
#  [999]]
#
#
# Query vector:
# [[[950]
#   [951]
#   [952]
#   ...,
#   [997]
#   [998]
#   [999]]]
# /Users/mnpappo/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", input_shape=(50, 1), filters=4, kernel_size=5)`
#   # Remove the CWD from sys.path while we load stuff.
# /Users/mnpappo/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", kernel_size=5, filters=4)`
#   if sys.path[0] == '':
# Train on 940 samples, validate on 10 samples
# Epoch 1/25
# 940/940 [==============================] - 1s - loss: 53191.7167 - mean_absolute_error: 100.8309 - val_loss: 62.8730 - val_mean_absolute_error: 7.9286
# Epoch 2/25
# 940/940 [==============================] - 1s - loss: 173.1385 - mean_absolute_error: 11.0000 - val_loss: 351.1566 - val_mean_absolute_error: 18.7387
# Epoch 3/25
# 940/940 [==============================] - 1s - loss: 167.4170 - mean_absolute_error: 10.8950 - val_loss: 34.5782 - val_mean_absolute_error: 5.8796
# Epoch 4/25
# 940/940 [==============================] - 1s - loss: 158.6405 - mean_absolute_error: 10.6556 - val_loss: 116.2325 - val_mean_absolute_error: 10.7806
# Epoch 5/25
# 940/940 [==============================] - 1s - loss: 139.3381 - mean_absolute_error: 9.8484 - val_loss: 1.7073 - val_mean_absolute_error: 1.3051
# Epoch 6/25
# 940/940 [==============================] - 1s - loss: 136.1783 - mean_absolute_error: 9.7972 - val_loss: 1.1452 - val_mean_absolute_error: 1.0681
# Epoch 7/25
# 940/940 [==============================] - 1s - loss: 135.1035 - mean_absolute_error: 9.7960 - val_loss: 3.0091 - val_mean_absolute_error: 1.7336
# Epoch 8/25
# 940/940 [==============================] - 1s - loss: 114.6005 - mean_absolute_error: 9.1486 - val_loss: 55.2920 - val_mean_absolute_error: 7.4355
# Epoch 9/25
# 940/940 [==============================] - 1s - loss: 82.5113 - mean_absolute_error: 7.6841 - val_loss: 3.2337 - val_mean_absolute_error: 1.7975
# Epoch 10/25
# 940/940 [==============================] - 1s - loss: 63.3983 - mean_absolute_error: 6.6826 - val_loss: 24.0852 - val_mean_absolute_error: 4.9074
# Epoch 11/25
# 940/940 [==============================] - 1s - loss: 59.9484 - mean_absolute_error: 6.5791 - val_loss: 13.6915 - val_mean_absolute_error: 3.6999
# Epoch 12/25
# 940/940 [==============================] - 1s - loss: 50.1441 - mean_absolute_error: 5.8505 - val_loss: 1.1445 - val_mean_absolute_error: 1.0695
# Epoch 13/25
# 940/940 [==============================] - 1s - loss: 48.3675 - mean_absolute_error: 5.4783 - val_loss: 11.5718 - val_mean_absolute_error: 3.4016
# Epoch 14/25
# 940/940 [==============================] - 1s - loss: 41.4108 - mean_absolute_error: 4.9588 - val_loss: 1.8300 - val_mean_absolute_error: 1.3525
# Epoch 15/25
# 940/940 [==============================] - 1s - loss: 15.4346 - mean_absolute_error: 3.3070 - val_loss: 10.4944 - val_mean_absolute_error: 3.2395
# Epoch 16/25
# 940/940 [==============================] - 1s - loss: 9.8507 - mean_absolute_error: 2.5720 - val_loss: 7.6549 - val_mean_absolute_error: 2.7667
# Epoch 17/25
# 940/940 [==============================] - 1s - loss: 8.4169 - mean_absolute_error: 2.2581 - val_loss: 0.0582 - val_mean_absolute_error: 0.2412
# Epoch 18/25
# 940/940 [==============================] - 1s - loss: 7.7901 - mean_absolute_error: 1.8236 - val_loss: 0.2179 - val_mean_absolute_error: 0.4668
# Epoch 19/25
# 940/940 [==============================] - 1s - loss: 9.3336 - mean_absolute_error: 1.8248 - val_loss: 5.5337 - val_mean_absolute_error: 2.3524
# Epoch 20/25
# 940/940 [==============================] - 1s - loss: 3.4906 - mean_absolute_error: 1.2634 - val_loss: 0.0076 - val_mean_absolute_error: 0.0869
# Epoch 21/25
# 940/940 [==============================] - 1s - loss: 14.2272 - mean_absolute_error: 2.0045 - val_loss: 0.0633 - val_mean_absolute_error: 0.2516
# Epoch 22/25
# 940/940 [==============================] - 1s - loss: 4.0385 - mean_absolute_error: 1.0633 - val_loss: 0.0030 - val_mean_absolute_error: 0.0547
# Epoch 23/25
# 940/940 [==============================] - 1s - loss: 0.1529 - mean_absolute_error: 0.2900 - val_loss: 0.1001 - val_mean_absolute_error: 0.3164
# Epoch 24/25
# 940/940 [==============================] - 1s - loss: 3.9823 - mean_absolute_error: 1.1649 - val_loss: 7.5082e-05 - val_mean_absolute_error: 0.0086
# Epoch 25/25
# 940/940 [==============================] - 1s - loss: 0.7581 - mean_absolute_error: 0.3569 - val_loss: 14.7936 - val_mean_absolute_error: 3.8462
#
#
# actual	predicted
# 990	986.171
# 991	987.167
# 992	988.163
# 993	989.16
# 994	990.156
# 995	991.152
# 996	992.148
# 997	993.144
# 998	994.14
# 999	995.136
# next	996.132629395
#
# Multiple-input, multiple-output prediction
#
#
# Timeseries (1000 samples by 2 series):
#  [[   0    0]
#  [   1   -1]
#  [   2   -2]
#  ...,
#  [ 997 -997]
#  [ 998 -998]
#  [ 999 -999]]
# /Users/mnpappo/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", input_shape=(50, 2), filters=4, kernel_size=5)`
#   # Remove the CWD from sys.path while we load stuff.
# Model with input size (None, 50, 2), output size (None, 2), 4 conv filters of length 5
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_7 (Conv1D)            (None, 46, 4)             44
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 23, 4)             0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 19, 4)             84
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 9, 4)              0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 36)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 74
# =================================================================
# Total params: 202
# Trainable params: 202
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Input features:
# [[[   0    0]
#   [   1   -1]
#   [   2   -2]
#   ...,
#   [  47  -47]
#   [  48  -48]
#   [  49  -49]]
#
#  [[   1   -1]
#   [   2   -2]
#   [   3   -3]
#   ...,
#   [  48  -48]
#   [  49  -49]
#   [  50  -50]]
#
#  [[   2   -2]
#   [   3   -3]
#   [   4   -4]
#   ...,
#   [  49  -49]
#   [  50  -50]
#   [  51  -51]]
#
#  ...,
#  [[ 947 -947]
#   [ 948 -948]
#   [ 949 -949]
#   ...,
#   [ 994 -994]
#   [ 995 -995]
#   [ 996 -996]]
#
#  [[ 948 -948]
#   [ 949 -949]
#   [ 950 -950]
#   ...,
#   [ 995 -995]
#   [ 996 -996]
#   [ 997 -997]]
#
#  [[ 949 -949]
#   [ 950 -950]
#   [ 951 -951]
#   ...,
#   [ 996 -996]
#   [ 997 -997]
#   [ 998 -998]]]
#
#
# Output labels:
# [[  50  -50]
#  [  51  -51]
#  [  52  -52]
#  ...,
#  [ 997 -997]
#  [ 998 -998]
#  [ 999 -999]]
#
#
# Query vector:
# [[[ 950 -950]
#   [ 951 -951]
#   [ 952 -952]
#   ...,
#   [ 997 -997]
#   [ 998 -998]
#   [ 999 -999]]]
# Train on 940 samples, validate on 10 samples
# Epoch 1/25
# 940/940 [==============================] - 1s - loss: 32178.0472 - mean_absolute_error: 71.9652 - val_loss: 224.2663 - val_mean_absolute_error: 14.9369
# Epoch 2/25
# 940/940 [==============================] - 1s - loss: 182.9246 - mean_absolute_error: 11.2253 - val_loss: 265.8778 - val_mean_absolute_error: 16.1762
# Epoch 3/25
# 940/940 [==============================] - 1s - loss: 178.4787 - mean_absolute_error: 11.1157 - val_loss: 14.5802 - val_mean_absolute_error: 3.6277
# Epoch 4/25
# 940/940 [==============================] - 1s - loss: 177.1137 - mean_absolute_error: 11.0722 - val_loss: 114.2879 - val_mean_absolute_error: 10.5319
# Epoch 5/25
# 940/940 [==============================] - 1s - loss: 176.7576 - mean_absolute_error: 11.1631 - val_loss: 271.9674 - val_mean_absolute_error: 16.3383
# Epoch 6/25
# 940/940 [==============================] - 1s - loss: 162.1123 - mean_absolute_error: 10.6114 - val_loss: 688.4245 - val_mean_absolute_error: 26.2374
# Epoch 7/25
# 940/940 [==============================] - 1s - loss: 159.6216 - mean_absolute_error: 10.6832 - val_loss: 343.5515 - val_mean_absolute_error: 18.4903
# Epoch 8/25
# 940/940 [==============================] - 1s - loss: 139.6969 - mean_absolute_error: 9.9936 - val_loss: 74.2204 - val_mean_absolute_error: 8.2953
# Epoch 9/25
# 940/940 [==============================] - 1s - loss: 142.6796 - mean_absolute_error: 10.0841 - val_loss: 226.0001 - val_mean_absolute_error: 14.7374
# Epoch 10/25
# 940/940 [==============================] - 1s - loss: 127.7682 - mean_absolute_error: 9.5560 - val_loss: 125.3835 - val_mean_absolute_error: 11.1723
# Epoch 11/25
# 940/940 [==============================] - 1s - loss: 98.0757 - mean_absolute_error: 8.3058 - val_loss: 45.7423 - val_mean_absolute_error: 6.1085
# Epoch 12/25
# 940/940 [==============================] - 1s - loss: 101.5026 - mean_absolute_error: 8.5530 - val_loss: 1.4215 - val_mean_absolute_error: 1.0929
# Epoch 13/25
# 940/940 [==============================] - 1s - loss: 88.8923 - mean_absolute_error: 7.8720 - val_loss: 86.7270 - val_mean_absolute_error: 9.1487
# Epoch 14/25
# 940/940 [==============================] - 1s - loss: 71.1303 - mean_absolute_error: 7.0524 - val_loss: 28.4287 - val_mean_absolute_error: 4.1738
# Epoch 15/25
# 940/940 [==============================] - 1s - loss: 65.2929 - mean_absolute_error: 6.6600 - val_loss: 89.8020 - val_mean_absolute_error: 9.4720
# Epoch 16/25
# 940/940 [==============================] - 1s - loss: 59.9115 - mean_absolute_error: 6.4846 - val_loss: 582.3066 - val_mean_absolute_error: 24.0712
# Epoch 17/25
# 940/940 [==============================] - 1s - loss: 43.6952 - mean_absolute_error: 5.4182 - val_loss: 53.2897 - val_mean_absolute_error: 6.9921
# Epoch 18/25
# 940/940 [==============================] - 1s - loss: 35.4424 - mean_absolute_error: 4.9285 - val_loss: 55.5790 - val_mean_absolute_error: 7.4046
# Epoch 19/25
# 940/940 [==============================] - 1s - loss: 27.9937 - mean_absolute_error: 4.3265 - val_loss: 20.4806 - val_mean_absolute_error: 3.7733
# Epoch 20/25
# 940/940 [==============================] - 1s - loss: 46.5479 - mean_absolute_error: 5.3562 - val_loss: 5.8835 - val_mean_absolute_error: 2.4181
# Epoch 21/25
# 940/940 [==============================] - 1s - loss: 30.8398 - mean_absolute_error: 4.0634 - val_loss: 1.9250 - val_mean_absolute_error: 1.3853
# Epoch 22/25
# 940/940 [==============================] - 1s - loss: 13.7870 - mean_absolute_error: 3.0685 - val_loss: 7.9998 - val_mean_absolute_error: 2.3864
# Epoch 23/25
# 940/940 [==============================] - 1s - loss: 13.2011 - mean_absolute_error: 2.8978 - val_loss: 0.7581 - val_mean_absolute_error: 0.8078
# Epoch 24/25
# 940/940 [==============================] - 1s - loss: 25.7194 - mean_absolute_error: 3.3780 - val_loss: 3.0009 - val_mean_absolute_error: 1.7297
# Epoch 25/25
# 940/940 [==============================] - 1s - loss: 13.4204 - mean_absolute_error: 2.7915 - val_loss: 15.6783 - val_mean_absolute_error: 3.8923
#
#
# actual	predicted
# [ 990 -990]	[ 993.14404297 -994.57348633]
# [ 991 -991]	[ 994.14892578 -995.5836792 ]
# [ 992 -992]	[ 995.15380859 -996.59356689]
# [ 993 -993]	[ 996.15869141 -997.60357666]
# [ 994 -994]	[ 997.16357422 -998.61364746]
# [ 995 -995]	[ 998.16851807 -999.62359619]
# [ 996 -996]	[  999.17346191 -1000.63360596]
# [ 997 -997]	[ 1000.17828369 -1001.64361572]
# [ 998 -998]	[ 1001.18322754 -1002.65362549]
# [ 999 -999]	[ 1002.18817139 -1003.66363525]
# next	[ 1003.19293213 -1004.67364502]
